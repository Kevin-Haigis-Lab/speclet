# %% [markdown]
# # Check of modeling data

# %%
from pathlib import Path

import dask.dataframe as dd
import numpy as np
import pandas as pd
from dask.distributed import Client, progress

# %%
client = Client(n_workers=4, threads_per_worker=2, memory_limit="32GB")
client
# Out:
# <Client: 'tcp://127.0.0.1:39738' processes=4 threads=8, memory=119.21 GiB>

# %% [markdown]
# Papermill parameters:
#
# `depmap_modeling_df`: The path to the full DepMap modeling data set.

# %%
DEPMAP_MODELING_DF: str = ""

# %%
# Parameters
DEPMAP_MODELING_DF = "../modeling_data/depmap-modeling-data.csv"

# %%
assert DEPMAP_MODELING_DF != "", "No path provided for the modeling data."

# %%
depmap_modeling_df_path = Path(DEPMAP_MODELING_DF)

if not depmap_modeling_df_path.exists():
    raise FileNotFoundError(f"Could not find '{str(depmap_modeling_df_path)}'")

# %%
pd.read_csv(depmap_modeling_df_path, low_memory=False, nrows=200)
# Out:
#                    sgrna replicate_id       lfc             p_dna_batch  \
# 0    AAACCTGCGGCGGTCGCCA  OVR3_c905R1 -0.299958  CRISPR_C6596666.sample
# 1    AACAGCACACCGGCCCCGT  OVR3_c905R1  0.267092  CRISPR_C6596666.sample
# 2    AACCTCCGGACTCCTCAGC  OVR3_c905R1  0.550477  CRISPR_C6596666.sample
# 3    AACTCAAACTGACGCCGAA  OVR3_c905R1 -0.391922  CRISPR_C6596666.sample
# 4    AACTGACCTTGAAACGCTG  OVR3_c905R1 -1.562577  CRISPR_C6596666.sample
# ..                   ...          ...       ...                     ...
# 195  TGAGCTGGCAATGCTAGAT  OVR3_c905R1  0.565344  CRISPR_C6596666.sample
# 196  TGATGGAGCGAATCAGATG  OVR3_c905R1 -0.204959  CRISPR_C6596666.sample
# 197  TGCACTTATGTGTGCCGCC  OVR3_c905R1  0.650650  CRISPR_C6596666.sample
# 198  TGCTAGGACCCAACTGAGC  OVR3_c905R1 -0.517796  CRISPR_C6596666.sample
# 199  TGGAAAGTTGCCTCGTCCG  OVR3_c905R1 -0.218348  CRISPR_C6596666.sample
#
#      genome_alignment hugo_symbol  screen  multiple_hits_on_gene  \
# 0     chr8_66505451_-         VXN  sanger                   True
# 1    chrX_156009834_-        IL9R  sanger                   True
# 2     chr7_39609658_-        YAE1  sanger                   True
# 3    chr1_117623388_-      TENT5C  sanger                   True
# 4    chr16_66933623_+      CIAO2B  sanger                   True
# ..                ...         ...     ...                    ...
# 195  chrX_155774116_-       SPRY3  sanger                   True
# 196  chr16_66934065_+      CIAO2B  sanger                   True
# 197  chrX_156003692_-        IL9R  sanger                   True
# 198  chr10_46580364_+       SYT15  sanger                   True
# 199  chr1_117622978_-      TENT5C  sanger                   True
#
#     sgrna_target_chr  sgrna_target_pos  ... any_deleterious  any_tcga_hotspot  \
# 0                  8          66505451  ...             NaN               NaN
# 1                  X         156009834  ...             NaN               NaN
# 2                  7          39609658  ...             NaN               NaN
# 3                  1         117623388  ...             NaN               NaN
# 4                 16          66933623  ...             NaN               NaN
# ..               ...               ...  ...             ...               ...
# 195                X         155774116  ...             NaN               NaN
# 196               16          66934065  ...             NaN               NaN
# 197                X         156003692  ...             NaN               NaN
# 198               10          46580364  ...             NaN               NaN
# 199                1         117622978  ...             NaN               NaN
#
#      any_cosmic_hotspot  is_mutated  copy_number  lineage  \
# 0                   NaN       False     1.139595    ovary
# 1                   NaN       False     0.656377    ovary
# 2                   NaN       False     0.923715    ovary
# 3                   NaN       False     1.352975    ovary
# 4                   NaN       False     1.157211    ovary
# ..                  ...         ...          ...      ...
# 195                 NaN       False     0.656377    ovary
# 196                 NaN       False     1.157211    ovary
# 197                 NaN       False     0.656377    ovary
# 198                 NaN       False     0.752471    ovary
# 199                 NaN       False     1.352975    ovary
#
#           lineage_subtype  primary_or_metastasis  is_male  age
# 0    ovary_adenocarcinoma             metastasis    False   60
# 1    ovary_adenocarcinoma             metastasis    False   60
# 2    ovary_adenocarcinoma             metastasis    False   60
# 3    ovary_adenocarcinoma             metastasis    False   60
# 4    ovary_adenocarcinoma             metastasis    False   60
# ..                    ...                    ...      ...  ...
# 195  ovary_adenocarcinoma             metastasis    False   60
# 196  ovary_adenocarcinoma             metastasis    False   60
# 197  ovary_adenocarcinoma             metastasis    False   60
# 198  ovary_adenocarcinoma             metastasis    False   60
# 199  ovary_adenocarcinoma             metastasis    False   60
#
# [200 rows x 25 columns]

# %%
depmap_modeling_df = dd.read_csv(
    depmap_modeling_df_path,
    dtype={
        "age": "float64",
        "p_dna_batch": "object",
        "primary_or_metastasis": "object",
        "counts_final": "float64",
        "counts_initial": "float64",
    },
    low_memory=False,
)

# %%
depmap_modeling_df.head()
# Out:
#                  sgrna replicate_id       lfc             p_dna_batch  \
# 0  AAACCTGCGGCGGTCGCCA  OVR3_c905R1 -0.299958  CRISPR_C6596666.sample
# 1  AACAGCACACCGGCCCCGT  OVR3_c905R1  0.267092  CRISPR_C6596666.sample
# 2  AACCTCCGGACTCCTCAGC  OVR3_c905R1  0.550477  CRISPR_C6596666.sample
# 3  AACTCAAACTGACGCCGAA  OVR3_c905R1 -0.391922  CRISPR_C6596666.sample
# 4  AACTGACCTTGAAACGCTG  OVR3_c905R1 -1.562577  CRISPR_C6596666.sample
#
#    genome_alignment hugo_symbol  screen  multiple_hits_on_gene  \
# 0   chr8_66505451_-         VXN  sanger                   True
# 1  chrX_156009834_-        IL9R  sanger                   True
# 2   chr7_39609658_-        YAE1  sanger                   True
# 3  chr1_117623388_-      TENT5C  sanger                   True
# 4  chr16_66933623_+      CIAO2B  sanger                   True
#
#   sgrna_target_chr  sgrna_target_pos  ... any_deleterious  any_tcga_hotspot  \
# 0                8          66505451  ...             NaN               NaN
# 1                X         156009834  ...             NaN               NaN
# 2                7          39609658  ...             NaN               NaN
# 3                1         117623388  ...             NaN               NaN
# 4               16          66933623  ...             NaN               NaN
#
#    any_cosmic_hotspot  is_mutated  copy_number  lineage       lineage_subtype  \
# 0                 NaN       False     1.139595    ovary  ovary_adenocarcinoma
# 1                 NaN       False     0.656377    ovary  ovary_adenocarcinoma
# 2                 NaN       False     0.923715    ovary  ovary_adenocarcinoma
# 3                 NaN       False     1.352975    ovary  ovary_adenocarcinoma
# 4                 NaN       False     1.157211    ovary  ovary_adenocarcinoma
#
#    primary_or_metastasis  is_male   age
# 0             metastasis    False  60.0
# 1             metastasis    False  60.0
# 2             metastasis    False  60.0
# 3             metastasis    False  60.0
# 4             metastasis    False  60.0
#
# [5 rows x 25 columns]

# %%
depmap_modeling_df.columns
# Out:
# Index(['sgrna', 'replicate_id', 'lfc', 'p_dna_batch', 'genome_alignment',
#        'hugo_symbol', 'screen', 'multiple_hits_on_gene', 'sgrna_target_chr',
#        'sgrna_target_pos', 'depmap_id', 'counts_final', 'counts_initial',
#        'rna_expr', 'num_mutations', 'any_deleterious', 'any_tcga_hotspot',
#        'any_cosmic_hotspot', 'is_mutated', 'copy_number', 'lineage',
#        'lineage_subtype', 'primary_or_metastasis', 'is_male', 'age'],
#       dtype='object')

# %% [markdown]
# ## Basic checks

# %%
FAILED_CHECKS = 0

# %% [markdown]
# Check that specific columns exist (prevents some really bonehead discoveries later on...).

# %%
cols_that_should_exist = [
    "depmap_id",
    "sgrna",
    "hugo_symbol",
    "lfc",
    "screen",
    "num_mutations",
    "is_mutated",
    "lineage",
    "counts_final",
    "p_dna_batch",
    "primary_or_metastasis",
]

missing_cols = [
    col for col in cols_that_should_exist if col not in depmap_modeling_df.columns
]
if len(missing_cols) != 0:
    print(f"Some columns ({len(missing_cols)}) that should be present are not 😦")
    print("  missing columns: " + ", ".join(missing_cols))
    FAILED_CHECKS += 1

# %% [markdown]
# Check that specific columns have no missing (`NA`) values.

# %%
cols_without_na = [
    "depmap_id",
    "sgrna",
    "hugo_symbol",
    "lfc",
    "screen",
    "num_mutations",
    "is_mutated",
    "lineage",
]

na_checks = depmap_modeling_df.isna()[cols_without_na].any().compute()
num_missed_checks = na_checks.sum()

if num_missed_checks > 0:
    FAILED_CHECKS += num_missed_checks
    print(na_checks[na_checks])

# %%
na_checks
# Out:
# depmap_id        False
# sgrna            False
# hugo_symbol      False
# lfc              False
# screen           False
# num_mutations    False
# is_mutated       False
# lineage          False
# dtype: bool

# %% [markdown]
# Check that all combinations of cell line, sgRNA, and experimental replicate only appear once.

# %%
grp_cols = ["depmap_id", "sgrna", "replicate_id"]
ct_df = (
    depmap_modeling_df.assign(n=1)[grp_cols + ["n"]]
    .groupby(grp_cols)
    .count()
    .query("n > 1")
    .compute()
)

if not ct_df.shape[0] == 0:
    print("There are some sgRNA with multiple targets.")
    print(ct_df.head(20))
    FAILED_CHECKS += 1

# %%
if FAILED_CHECKS > 0:
    raise Exception(f"There were {FAILED_CHECKS} failed checks.")

# %% [markdown]
# ---

# %%
# %load_ext watermark
# %watermark -d -u -v -iv -b -h -m
# Out:
# Last updated: 2022-05-15
#
# Python implementation: CPython
# Python version       : 3.10.4
# IPython version      : 8.3.0
#
# Compiler    : GCC 10.3.0
# OS          : Linux
# Release     : 3.10.0-1160.45.1.el7.x86_64
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 28
# Architecture: 64bit
#
# Hostname: compute-e-16-229.o2.rc.hms.harvard.edu
#
# Git branch: crc-panc-eso
#
# numpy : 1.22.3
# dask  : 2022.5.0
# pandas: 1.4.2
